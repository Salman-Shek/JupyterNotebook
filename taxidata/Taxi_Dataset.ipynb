# %%
import pandas as pd
df = pd.read_csv("taxi_raw_data.csv",dtype=None)
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1       12/1/2018 0:28        12/1/2018 0:44                2
# 1             1       12/1/2018 0:52        12/1/2018 1:11                3
# 2             2       12/1/2018 0:12        12/1/2018 0:36                1
# 3             1       12/1/2018 0:35        12/1/2018 0:43                1
# 4             1       12/1/2018 0:21        12/1/2018 1:15                1
# ...         ...                  ...                   ...              ...
# 10010         1       12/1/2018 0:39        12/1/2018 0:45                1
# 10011         1       12/1/2018 0:49        12/1/2018 0:57                1
# 10012         2       12/1/2018 0:02        12/1/2018 0:14                2
# 10013         1       12/1/2018 0:05        12/1/2018 0:16                1
# 10014         1       12/1/2018 0:18        12/1/2018 0:30                1
#
# ...

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1       12/1/2018 0:28        12/1/2018 0:44                2
# 1         1       12/1/2018 0:52        12/1/2018 1:11                3
# 2         2       12/1/2018 0:12        12/1/2018 0:36                1
# 3         1       12/1/2018 0:35        12/1/2018 0:43                1
# 4         1       12/1/2018 0:21        12/1/2018 1:15                1
#
#    trip_distance  PULocationID  DOLocationID  RatecodeID  payment_type  \
# 0            2.5         148.0         234.0         1.0           1.0
# 1            2.3         170.0         144.0         1.0           1.0
# 2            0.0         113.0         193.0         1.0           2.0
# 3            3.9          95.0          92.0         1.0           1.0
# 4           12.8         163.0         228.0         1.0           1.0
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.describe()
# Out:
#            VendorID  passenger_count  trip_distance  PULocationID  \
# count  10015.000000     10015.000000   10015.000000  10014.000000
# mean       1.605592         1.704543       2.952141    154.376972
# std        0.488748         1.278587       3.114570     66.993062
# min        1.000000         0.000000       0.000000      4.000000
# 25%        1.000000         1.000000       1.100000    100.250000
# 50%        2.000000         1.000000       1.900000    151.000000
# 75%        2.000000         2.000000       3.620000    230.000000
# max        2.000000         6.000000      32.800000    265.000000
#
#        DOLocationID    RatecodeID  payment_type   fare_amount         extra  \
# count  10012.000000  10014.000000  10013.000000  10012.000000  10014.000000
# mean     151.717539      1.023867      1.265954     12.669439      0.491891
# std       74.351299      0.253074      0.467348     10.186656      0.069941
# ...

# %%
df1=df.loc[df['PULocationID']==0.00,'PULocationID']
print(df1)
# Out:
# Series([], Name: PULocationID, dtype: float64)

# %%
df.loc[df['DOLocationID']==161]
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 201          2       12/1/2018 0:41        12/1/2018 0:49                4
# 226          2       12/1/2018 0:44        12/1/2018 0:54                1
# 372          1       12/1/2018 0:43        12/1/2018 0:50                1
# 396          1       12/1/2018 0:16        12/1/2018 0:30                1
# 423          1       12/1/2018 0:22        12/1/2018 0:32                1
# ...        ...                  ...                   ...              ...
# 9479         1       12/1/2018 0:16        12/1/2018 0:17                0
# 9507         2       12/1/2018 0:06        12/1/2018 0:10                5
# 9609         2       12/1/2018 0:17        12/1/2018 0:22                2
# 9757         1       12/1/2018 0:29        12/1/2018 0:29                1
# 9981         2       12/1/2018 0:12        12/1/2018 0:17                1
#
# ...

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1       12/1/2018 0:28        12/1/2018 0:44                2
# 1             1       12/1/2018 0:52        12/1/2018 1:11                3
# 2             2       12/1/2018 0:12        12/1/2018 0:36                1
# 3             1       12/1/2018 0:35        12/1/2018 0:43                1
# 4             1       12/1/2018 0:21        12/1/2018 1:15                1
# ...         ...                  ...                   ...              ...
# 10010         1       12/1/2018 0:39        12/1/2018 0:45                1
# 10011         1       12/1/2018 0:49        12/1/2018 0:57                1
# 10012         2       12/1/2018 0:02        12/1/2018 0:14                2
# 10013         1       12/1/2018 0:05        12/1/2018 0:16                1
# 10014         1       12/1/2018 0:18        12/1/2018 0:30                1
#
# ...

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'PULocationID', 'DOLocationID',
#        'RatecodeID', 'payment_type', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'New_Total', 'check'],
#       dtype='object')

# %%
df.describe()
# Out:
#            VendorID  passenger_count  trip_distance  PULocationID  \
# count  10015.000000     10015.000000   10015.000000  10014.000000
# mean       1.605592         1.704543       2.952141    154.376972
# std        0.488748         1.278587       3.114570     66.993062
# min        1.000000         0.000000       0.000000      4.000000
# 25%        1.000000         1.000000       1.100000    100.250000
# 50%        2.000000         1.000000       1.900000    151.000000
# 75%        2.000000         2.000000       3.620000    230.000000
# max        2.000000         6.000000      32.800000    265.000000
#
#        DOLocationID    RatecodeID  payment_type   fare_amount         extra  \
# count  10012.000000  10014.000000  10013.000000  10012.000000  10014.000000
# mean     151.717539      1.023867      1.265954     12.669439      0.491891
# std       74.351299      0.253074      0.467348     10.186656      0.069941
# ...

# %%
df['New_Total'] = df['fare_amount']+df['extra']+df['mta_tax']+df['tip_amount']+df['tolls_amount']+df['improvement_surcharge']

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1       12/1/2018 0:28        12/1/2018 0:44                2
# 1             1       12/1/2018 0:52        12/1/2018 1:11                3
# 2             2       12/1/2018 0:12        12/1/2018 0:36                1
# 3             1       12/1/2018 0:35        12/1/2018 0:43                1
# 4             1       12/1/2018 0:21        12/1/2018 1:15                1
# ...         ...                  ...                   ...              ...
# 10010         1       12/1/2018 0:39        12/1/2018 0:45                1
# 10011         1       12/1/2018 0:49        12/1/2018 0:57                1
# 10012         2       12/1/2018 0:02        12/1/2018 0:14                2
# 10013         1       12/1/2018 0:05        12/1/2018 0:16                1
# 10014         1       12/1/2018 0:18        12/1/2018 0:30                1
#
# ...

# %%
(df['total_amount']).equals(df['New_Total'])
# Out:
# False

# %%
import numpy as np

# %%
df['check'] = np.where((df['total_amount']!=df['New_Total']),False,True)

# %%
df.loc[df['check']==False].head()
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1          1       12/1/2018 0:52        12/1/2018 1:11                3
# 9          1       12/1/2018 0:16        12/1/2018 0:52                1
# 17         1       12/1/2018 0:42        12/1/2018 0:55                1
# 22         1       12/1/2018 0:03        12/1/2018 0:15                2
# 26         2       12/1/2018 0:11        12/1/2018 0:45                1
#
#     trip_distance  PULocationID  DOLocationID  RatecodeID  payment_type  \
# 1             2.3         170.0         144.0         1.0           1.0
# 9             5.7         161.0         223.0         1.0           1.0
# 17            3.9         148.0         140.0         1.0           1.0
# 22            1.7         148.0          90.0         1.0           1.0
# 26            7.7          48.0         106.0         1.0           1.0
#
#     fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.drop(columns='check')
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1       12/1/2018 0:28        12/1/2018 0:44                2
# 1             1       12/1/2018 0:52        12/1/2018 1:11                3
# 2             2       12/1/2018 0:12        12/1/2018 0:36                1
# 3             1       12/1/2018 0:35        12/1/2018 0:43                1
# 4             1       12/1/2018 0:21        12/1/2018 1:15                1
# ...         ...                  ...                   ...              ...
# 10010         1       12/1/2018 0:39        12/1/2018 0:45                1
# 10011         1       12/1/2018 0:49        12/1/2018 0:57                1
# 10012         2       12/1/2018 0:02        12/1/2018 0:14                2
# 10013         1       12/1/2018 0:05        12/1/2018 0:16                1
# 10014         1       12/1/2018 0:18        12/1/2018 0:30                1
#
# ...

# %%
df2 = np.where(df['DOLocationID'] == 0)

# %%
df2
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### adding new column count =1 to do count of records while using groupby

# %%
df['count'] = 1

# %%
df.groupby(['VendorID']).count() [['count']]
# Out:
#           count
# VendorID
# 1          3950
# 2          6065

# %%
df2 = df.groupby(['VendorID']).sum() [['total_amount']]
df2
# Out:
#           total_amount
# VendorID
# 1             62365.92
# 2             97685.13

# %%
df3 = df.loc[df['passenger_count']>4,['VendorID','passenger_count']]

# %%
df3.head(10)
# Out:
#      VendorID  passenger_count
# 101         2                5
# 102         2                5
# 103         2                5
# 169         2                5
# 170         2                5
# 227         2                5
# 232         2                5
# 292         2                6
# 293         2                6
# 294         2                6

# %%
df4 = df.loc[df['trip_distance']==0]
df4.head(10)
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2            2       12/1/2018 0:12        12/1/2018 0:36                1
# 313          2       12/1/2018 0:40        12/1/2018 0:41                3
# 495          2       12/1/2018 0:27        12/1/2018 0:29                4
# 508          1       12/1/2018 0:22        12/1/2018 0:22                1
# 516          2       12/1/2018 0:16        12/1/2018 0:17                1
# 944          2       12/1/2018 0:08        12/1/2018 0:08                1
# 1174         2       12/1/2018 0:40        12/1/2018 0:40                1
# 1525         1       12/1/2018 0:39        12/1/2018 0:54                1
# 2005         2       12/1/2018 0:18        12/1/2018 0:18                1
# 2242         2       12/1/2018 0:02        12/1/2018 0:02                1
#
#       trip_distance  PULocationID  DOLocationID  RatecodeID  payment_type  \
# ...

# %%
df5 = df.loc[(df['trip_distance']==0) & (df['total_amount']>0)]
df5.tail(10)
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 8760         2       12/1/2018 0:14        12/1/2018 0:15                2
# 8946         2       12/1/2018 0:35        12/1/2018 0:35                1
# 9130         2       12/1/2018 0:43        12/1/2018 0:44                1
# 9398         1       12/1/2018 0:36        12/1/2018 0:36                1
# 9529         2       12/1/2018 0:58        12/1/2018 1:02                1
# 9550         1       12/1/2018 0:14        12/1/2018 0:14                1
# 9797         2       12/1/2018 0:25        12/1/2018 0:25                2
# 9874         1       12/1/2018 0:16        12/1/2018 0:18                1
# 9883         1       12/1/2018 0:50        12/1/2018 0:51                3
# 9897         2       12/1/2018 0:00        12/1/2018 0:01                5
#
#       trip_distance  PULocationID  DOLocationID  RatecodeID  payment_type  \
# ...

# %%
df5.to_csv("Trips_with_zero_distance.csv", index=False)

# %%
df6 = df.loc[df['total_amount']<0, ['VendorID','tpep_pickup_datetime','tpep_dropoff_datetime','trip_distance','total_amount']]
df6.head(10)
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  trip_distance  \
# 863          2       12/1/2018 0:33        12/1/2018 0:36           0.62
# 2242         2       12/1/2018 0:02        12/1/2018 0:02           0.00
# 4132         2       12/1/2018 0:52        12/1/2018 0:57           0.63
# 4424         2       12/1/2018 0:09        12/1/2018 0:09           0.03
# 4814         2       12/1/2018 0:04        12/1/2018 0:08           0.51
# 4878         2       12/1/2018 0:53        12/1/2018 1:30          14.55
# 5284         2       12/1/2018 0:56        12/1/2018 0:57           0.09
# 5433         2     11/30/2018 23:55      11/30/2018 23:56           0.15
# 6638         2       12/1/2018 0:50        12/1/2018 0:53           0.11
# 6718         2       12/1/2018 0:48        12/1/2018 0:59           2.45
#
#       total_amount
# 863          -5.30
# 2242         -3.80
# 4132         -6.30
# 4424         -3.80
# 4814         -5.80
# 4878        -56.93
# 5284         -4.30
# ...

# %%
df6.to_csv("Trips_with_negative_total.csv", index=False)

# %%
df7 = df.groupby(['payment_type']).count()
df7.iloc[:, 8:16]
# Out:
#               fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# payment_type
# 1.0                  7443   7443     7439        7442          7443
# 2.0                  2495   2497     2497        2497          2497
# 3.0                    50     50       50          50            50
# 4.0                    22     22       22          22            22
#
#               improvement_surcharge  total_amount  New_Total
# payment_type
# 1.0                            7443          7444       7435
# 2.0                            2497          2496       2495
# 3.0                              50            50         50
# 4.0                              22            22         22

# %%
df['matching'] = df['total_amount']== df['New_Total']

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1       12/1/2018 0:28        12/1/2018 0:44                2
# 1             1       12/1/2018 0:52        12/1/2018 1:11                3
# 2             2       12/1/2018 0:12        12/1/2018 0:36                1
# 3             1       12/1/2018 0:35        12/1/2018 0:43                1
# 4             1       12/1/2018 0:21        12/1/2018 1:15                1
# ...         ...                  ...                   ...              ...
# 10010         1       12/1/2018 0:39        12/1/2018 0:45                1
# 10011         1       12/1/2018 0:49        12/1/2018 0:57                1
# 10012         2       12/1/2018 0:02        12/1/2018 0:14                2
# 10013         1       12/1/2018 0:05        12/1/2018 0:16                1
# 10014         1       12/1/2018 0:18        12/1/2018 0:30                1
#
# ...
